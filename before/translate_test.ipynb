# %%
# !pip install py-translate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 61 kB 3.4 MB/s
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/AI_contest/ansgkrtksghfkddl/ansgkrtksghfkddl.csv')
s = df['Findings'][0]
s
# Out:
# 'Clinical information : 두부외상 후 후유증 평가\r\n\r\nAxial T1WI, sagittal T1WI, axial T2WI, axial FLAIR, axial T2* GRE image 획득하였으며 조영증강은 시행하지 않았음.\r\n\n'

# %%
s1 = '두부 외상 후 후유증 평가. imgae 획득하였으며 조영증강은 시행하지 않았음. normal brain mri'

# %%
from translate import translator
translator= translator('en', 'ko', s1)
translator
# Out:
# [[['두부 두부 후 외상 평가. ',
#    '두부 외상 후 후유증 평가.',
#    None,
#    None,
#    3,
#    None,
#    None,
#    [[None, 'offline']],
#    [[['72e11e18e6e8ba5243a9f2ad6e857631', 'efficient_models_2022q2.md']]]],
#   ['Imgae하였으며 획득 조영 증강 증강은 시행하지 않았음. ',
#    'imgae 획득하였으며 조영증강은 시행하지 않았음.',
#    None,
#    None,
#    3,
#    None,
#    None,
#    [[None, 'offline']],
#    [[['72e11e18e6e8ba5243a9f2ad6e857631', 'efficient_models_2022q2.md']]]],
#   ['정상적인 뇌 MRI',
#    'normal brain mri',
#    None,
#    None,
#    3,
#    None,
#    None,
#    [[None, 'offline']],
#    [[['72e11e18e6e8ba5243a9f2ad6e857631', 'efficient_models_2022q2.md']]]]],
#  None,
#  'en',
#  None,
#  None,
#  None,
#  None,
#  []]
